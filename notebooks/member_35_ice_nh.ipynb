# %%
import xarray as xr

# %%
member_31 = "/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/ice/proc/tseries/daily/hi_d/b.e11.B20TRC5CNBDRD.f09_g16.031.cice.h1.hi_d_nh.19200101-20051231.nc"
member_35 = "/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/ice/proc/tseries/daily/hi_d/b.e11.B20TRC5CNBDRD.f09_g16.035.cice.h1.hi_d_nh.19200101-20051231.nc"

# %%
m_31 = xr.open_dataset(member_31, chunks={}, decode_times=False)
m_35 = xr.open_dataset(member_35, chunks={}, decode_times=False)

# %%
m_31.time.plot()

# %%
m_35.time.plot()  # Member 35 time axis is wrong

# %%
m_31.time.min(), m_31.time.max()
# Out:
# (<xarray.DataArray 'time' ()>
#  array(700801., dtype=float32),
#  <xarray.DataArray 'time' ()>
#  array(732190., dtype=float32))

# %%
m_35.time.min(), m_35.time.max()
# Out:
# (<xarray.DataArray 'time' ()>
#  array(0., dtype=float32),
#  <xarray.DataArray 'time' ()>
#  array(732190., dtype=float32))

# %%
m_35.time.sortby("time")
# Out:
# <xarray.DataArray 'time' (time: 31390)>
# array([     0.,      0.,      0., ..., 732188., 732189., 732190.],
#       dtype=float32)
# Coordinates:
#   * time     (time) float32 0.0 0.0 0.0 700801.0 ... 732188.0 732189.0 732190.0
# Attributes:
#     long_name:  model time
#     units:      days since 0000-01-01 00:00:00
#     calendar:   noleap
#     bounds:     time_bounds

# %%
m_35.assign(time=m_31.time).time.plot()

# %%
m_35.time.min() == 0
# Out:
# <xarray.DataArray 'time' ()>
# array(True)
