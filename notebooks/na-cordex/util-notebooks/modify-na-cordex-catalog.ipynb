# %%
x = 'This is a string'
'string' in x
# Out:
# True

# %%
import pandas as pd

# %%
df = pd.read_csv('../../catalogs/glade-na-cordex.csv')

# %%
df
# Out:
#                                                     path variable scenario  \
# 0      /glade/collections/cdg/data/cordex/data/raw/NA...     prec     hist
# 1      /glade/collections/cdg/data/cordex/data/raw/NA...      vas     hist
# 2      /glade/collections/cdg/data/cordex/data/raw/NA...  sfcWind     hist
# 3      /glade/collections/cdg/data/cordex/data/raw/NA...      uas     hist
# 4      /glade/collections/cdg/data/cordex/data/raw/NA...      tas     hist
# ...                                                  ...      ...      ...
# 20443  /glade/collections/cdg/data/cordex/data/mbcn-D...     tmax    rcp85
# 20444  /glade/collections/cdg/data/cordex/data/mbcn-D...    tmean    rcp85
# 20445  /glade/collections/cdg/data/cordex/data/mbcn-D...     hurs    rcp85
# 20446  /glade/collections/cdg/data/cordex/data/mbcn-D...     huss    rcp85
# 20447  /glade/collections/cdg/data/cordex/data/mbcn-D...     tmin    rcp85
#
# ...

# %%
df['member_id'] = df['driver'] + '.' + df['rcm']

# %%
df
# Out:
#                                                     path variable scenario  \
# 0      /glade/collections/cdg/data/cordex/data/raw/NA...     prec     hist
# 1      /glade/collections/cdg/data/cordex/data/raw/NA...      vas     hist
# 2      /glade/collections/cdg/data/cordex/data/raw/NA...  sfcWind     hist
# 3      /glade/collections/cdg/data/cordex/data/raw/NA...      uas     hist
# 4      /glade/collections/cdg/data/cordex/data/raw/NA...      tas     hist
# ...                                                  ...      ...      ...
# 20443  /glade/collections/cdg/data/cordex/data/mbcn-D...     tmax    rcp85
# 20444  /glade/collections/cdg/data/cordex/data/mbcn-D...    tmean    rcp85
# 20445  /glade/collections/cdg/data/cordex/data/mbcn-D...     hurs    rcp85
# 20446  /glade/collections/cdg/data/cordex/data/mbcn-D...     huss    rcp85
# 20447  /glade/collections/cdg/data/cordex/data/mbcn-D...     tmin    rcp85
#
# ...

# %%
df.to_csv('./glade-na-cordex-bonnland.csv')

# %%
# !ls /glade/collections/cdg/data
# Out:
# AK_WRF				DCMIP_2016	      cesmLE
# ARTMIP				EAGLE		      cesmME
# ATL-PACEMAKER			GeoMIP		      cmip5
# CCMI1				GeoMIP-SSP5	      cola-sp-ccsm4
# CDP1				Gettelman_ECS_paper   community-data
# CESM1-CAM5-AllBut		IOD-PACEMAKER	      cordex
# CESM1-CCSM4_mid-Pliocene	IPO-PACEMAKER	      esg
# CESM1.3_SH_storm_tracks_dxyang	ISSI_OSSE	      esg-cdp
# CESM2-LE			PAST2K_ajahn	      esg_files_location
# CESM2.1_release			PMIP3		      facets
# CESM21-CISM2-JG-BG		SD-WACCM-X_v2.1       iTRACE-ts
# CLIVAR_LE			SOcean_Eddies_mclong  narccap
# CLM_LAND_ONLY_RELEASE		TAMIP		      nmme
# CMIP6				TC-CESM		      woelfle
