# %%
import xarray as xr

from helpers import create_grid_dataset, get_grid_vars

# %%
member_31 = "/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/ice/proc/tseries/daily/hi_d/b.e11.B20TRC5CNBDRD.f09_g16.031.cice.h1.hi_d_nh.19200101-20051231.nc"
ice_nh_grid = create_grid_dataset(member_31, variables=["hi_d"])
ice_nh_grid
# Out:
# <xarray.Dataset>
# Dimensions:      (ni: 320, nj: 104, nvertices: 4)
# Coordinates:
#     TLAT         (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     dyu          (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     ULON         (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     dxu          (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     blkmask      (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     tarea        (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     HTN          (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     uarea        (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     ANGLET       (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     HTE          (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     latu_bounds  (nj, ni, nvertices) float32 dask.array<chunksize=(104, 320, 4), meta=np.ndarray>
#     dyt          (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     TLON         (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     dxt          (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     latt_bounds  (nj, ni, nvertices) float32 dask.array<chunksize=(104, 320, 4), meta=np.ndarray>
#     ANGLE        (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     ULAT         (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     lonu_bounds  (nj, ni, nvertices) float32 dask.array<chunksize=(104, 320, 4), meta=np.ndarray>
#     tmask        (nj, ni) float32 dask.array<chunksize=(104, 320), meta=np.ndarray>
#     lont_bounds  (nj, ni, nvertices) float32 dask.array<chunksize=(104, 320, 4), meta=np.ndarray>
# Dimensions without coordinates: ni, nj, nvertices
# Data variables:
#     *empty*

# %%
# ice_nh_grid.to_zarr("/glade/scratch/abanihi/lens-aws/ice_nh/static/grid.zarr", consolidated=True)

# %%
member_31 = "/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/ice/proc/tseries/daily/hi_d/b.e11.B20TRC5CNBDRD.f09_g16.031.cice.h1.hi_d_sh.19200101-20051231.nc"
ice_sh_grid = create_grid_dataset(member_31, variables=["hi_d"])
ice_sh_grid
# Out:
# <xarray.Dataset>
# Dimensions:      (ni: 320, nj: 76, nvertices: 4)
# Coordinates:
#     TLAT         (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     dyu          (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     ULON         (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     dxu          (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     blkmask      (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     tarea        (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     HTN          (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     uarea        (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     ANGLET       (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     HTE          (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     latu_bounds  (nj, ni, nvertices) float32 dask.array<chunksize=(76, 320, 4), meta=np.ndarray>
#     dyt          (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     TLON         (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     dxt          (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     latt_bounds  (nj, ni, nvertices) float32 dask.array<chunksize=(76, 320, 4), meta=np.ndarray>
#     ANGLE        (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     ULAT         (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     lonu_bounds  (nj, ni, nvertices) float32 dask.array<chunksize=(76, 320, 4), meta=np.ndarray>
#     tmask        (nj, ni) float32 dask.array<chunksize=(76, 320), meta=np.ndarray>
#     lont_bounds  (nj, ni, nvertices) float32 dask.array<chunksize=(76, 320, 4), meta=np.ndarray>
# Dimensions without coordinates: ni, nj, nvertices
# Data variables:
#     *empty*

# %%
ice_sh_grid.to_zarr(
    "/glade/scratch/abanihi/lens-aws/ice_sh/static/grid.zarr", consolidated=True
)
