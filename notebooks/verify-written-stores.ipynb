# %%
from helpers import inspect_written_stores

# %%
dirout = "/glade/scratch/abanihi/data/lens-aws"
inspect_written_stores(dirout, random_sample_size=40)
# Out:
# Total number of discovered zarr stores: 374
# ...
# store path: /glade/scratch/abanihi/data/lens-aws/ocn/monthly/cesmLE-20C-DIC.zarr
# Time range: 1920-01-16 12:00:00 --> 2005-12-16 12:00:00
#
#
# store path: /glade/scratch/abanihi/data/lens-aws/ice_sh/monthly/cesmLE-20C-hi.zarr
# Time range: 1920-01-16 12:00:00 --> 2005-12-16 12:00:00
#
#
# store path: /glade/scratch/abanihi/data/lens-aws/atm/monthly/cesmLE-HIST-FSNTOA.zarr
# Time range: 1850-01-16 12:00:00 --> 1919-12-16 12:00:00
#
#
# store path: /glade/scratch/abanihi/data/lens-aws/atm/hourly6-1990-2005/cesmLE-20C-T.zarr
# Time range: 1990-01-01 00:00:00 --> 2006-01-01 00:00:00
#
#
# store path: /glade/scratch/abanihi/data/lens-aws/ocn/monthly/cesmLE-CTRL-UES.zarr
# Time range: 0400-01-16 12:00:00 --> 2200-12-16 12:00:00
#
#
# store path: /glade/scratch/abanihi/data/lens-aws/ocn/monthly/cesmLE-RCP85-UES.zarr
# Time range: 2006-01-16 12:00:00 --> 2100-12-16 12:00:00
#
#
# ...
