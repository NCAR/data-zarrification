# %%
import xarray as xr

# %%
ds = xr.open_dataset('/glade/scratch/bonnland/temp/lnd/0001/f.e21.FHIST_BGC.f09_025.CAM6assim.011.clm2_0001.h0.2011.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (hist_interval: 2, lat: 192, levdcmp: 25, levgrnd: 25, levlak: 10, lon: 288, time: 1460)
# Coordinates:
#   * levgrnd       (levgrnd) float32 0.01 0.04 0.09 0.16 ... 19.48 28.87 42.0
#   * levlak        (levlak) float32 0.05 0.6 2.1 4.6 ... 18.6 25.6 34.33 44.78
#   * levdcmp       (levdcmp) float32 0.01 0.04 0.09 0.16 ... 19.48 28.87 42.0
#   * time          (time) datetime64[ns] 2011-01-01 ... 2011-12-31T18:00:00
#   * lon           (lon) float32 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lat           (lat) float32 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
# Dimensions without coordinates: hist_interval
# Data variables: (12/23)
#     mcdate        (time) int32 ...
#     mcsec         (time) int32 ...
#     mdcur         (time) int32 ...
#     mscur         (time) int32 ...
#     nstep         (time) int32 ...
#     time_bounds   (time, hist_interval) datetime64[ns] ...
#     ...            ...
# ...

# %%
ds2 = xr.open_dataset('/glade/scratch/bonnland/temp/lnd/0001/f.e21.FHIST_BGC.f09_025.CAM6assim.011.clm2_0001.h1.2011.nc', decode_cf=False)
ds2
# Out:
# <xarray.Dataset>
# Dimensions:             (column: 504825, gridcell: 20932, hist_interval: 2, landunit: 61849, lat: 192, levdcmp: 25, levgrnd: 25, levlak: 10, lon: 288, pft: 797873, string_length: 16, time: 1460)
# Coordinates:
#   * levgrnd             (levgrnd) float32 0.01 0.04 0.09 ... 19.48 28.87 42.0
#   * levlak              (levlak) float32 0.05 0.6 2.1 4.6 ... 25.6 34.33 44.78
#   * levdcmp             (levdcmp) float32 0.01 0.04 0.09 ... 19.48 28.87 42.0
#   * time                (time) float32 0.0 0.25 0.5 0.75 ... 364.2 364.5 364.8
#   * lon                 (lon) float32 0.0 1.25 2.5 3.75 ... 356.2 357.5 358.8
#   * lat                 (lat) float32 -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
# Dimensions without coordinates: column, gridcell, hist_interval, landunit, pft, string_length
# Data variables: (12/56)
#     mcdate              (time) int32 ...
#     mcsec               (time) int32 ...
#     mdcur               (time) int32 ...
# ...
