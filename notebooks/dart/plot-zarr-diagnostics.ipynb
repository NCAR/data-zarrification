# %% [markdown]
# ## Make Diagnostic Plots for DART Reanalysis Zarr Stores

# %%
import xarray as xr
import numpy as np

import dask.distributed
from dask.distributed import Client
from ncar_jobqueue import NCARCluster

from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
from pathlib import Path
import os

import pprint
import json

# %% [markdown]
# ## Run These Cells for Dask CASPER

# %%
# Processes is processes PER CORE.
# This one works fine.
#cluster = NCARCluster(cores=15, processes=1, memory='100GB', project='STDD0003')
# This one also works, but occasionally hangs neacr the end.
#cluster = NCARCluster(cores=10, processes=1, memory='50GB', project='STDD0003')

# For Casper
num_cores = 2 #1
num_jobs = 50 #90 #4
walltime = "1:00:00" #"1:00:00"
memory = '50GB' #'50GB'

cluster = NCARCluster(cores=num_cores, processes=1, memory=memory, project='STDD0003', walltime=walltime)
cluster.scale(jobs=num_jobs)

client = Client(cluster)
cluster

# %% [markdown]
# ## Run These Cells for Dask CHEYENNE

# %%
# For Cheyenne

num_cores = 16
processes_per_node= 16
num_nodes = 2 
memory = '109GB'

# Consider that land variable maps are > 40 minutes each.
walltime = "4:30:00" #"2:00:00" 

# Run <= 4 workers on each node to avoid crashes.
cluster = NCARCluster(cores=num_cores, processes=processes_per_node, 
                      memory=memory, walltime=walltime)

cluster.scale(jobs=num_nodes)

from distributed import Client
from distributed.utils import format_bytes
client = Client(cluster)
cluster
# Out:
# Tab(children=(HTML(value='\n            <div class="jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-Ou…

# %% [markdown]
# ## Define Plot Functions

# %% [markdown]
# #### Hide unused subplot panels (Helper Function)

# %%
def hide_subplots(axes, start_row):
    '''Given an array of axes and a row index, hide plots with this row index or later.
    Subplot array can be 1-D or 2-D.
    '''
    subplot_ndims = axes.ndim
    if subplot_ndims == 1:
        nrows = len(axes)
        for row in np.arange(start_row, nrows):
            axes[row].axis('off')
    else:
        assert(subplot_ndims == 2)
        (nrows, ncols) = axes.shape
        for row in np.arange(start_row, nrows):
            for col in np.arange(ncols):
                axes[row][col].axis('off')

# %% [markdown]
# #### Get consistently shaped data slices for both 2D and 3D variables.

# %%
def getSlice(ds, data_var, member_id):
    '''If the data has vertical levels, choose the level closest
       to the Earth's surface for 2-D diagnostic plots.
    '''

    data_slice = ds[data_var].sel(member_id = member_id)

    if 'lev' in data_slice.dims:
        lastLevel = ds.lev.values[-1]
        data_slice = data_slice.sel(lev = lastLevel)
        data_slice = data_slice.squeeze()

    return data_slice

# %%
def getSpatialDimensionNames(data_slice):
    '''Get the spatial dimension names for this data slice.
    '''
    # Determine lat/lon conventions for this slice.
    lat_dim = 'lat' if 'lat' in data_slice.dims else 'slat'
    lon_dim = 'lon' if 'lon' in data_slice.dims else 'slon'
    
    return [lat_dim, lon_dim]

# %% [markdown]
# #### Create Single Map Plot (Helper Function)

# %%
def plotMap(ax, map_slice, date_object=None, member_id=None):
    '''Create a map plot on the given axes, with min/max as text'''

    ax.imshow(map_slice, origin='lower')
    
    spatial_dims = getSpatialDimensionNames(map_slice)
    minval = map_slice.min(dim = spatial_dims)
    maxval = map_slice.max(dim = spatial_dims)
            
    # Format values to have at least 4 digits of precision.
    text_height = 0.17
    ax.text(0.01, text_height, "%4g" % minval, transform=ax.transAxes, fontsize=12)
    ax.text(0.99, text_height, "%4g" % maxval, transform=ax.transAxes, fontsize=12, horizontalalignment='right')
    ax.set_xticks([])
    ax.set_yticks([])
    
    if date_object:
        ax.set_title(date_object.values.astype(str)[:10], fontsize=12)
        
    if member_id:
        ax.set_ylabel(member_id, fontsize=12)
        
    return ax

# %% [markdown]
# #### Create Statistical Map Plots Over Multiple Pages

# %%
def plot_stat_maps(ds, data_var, store_name, plotdir):
    # Generate plot. 
    #
    # With 30 workers, expect 1 minute walltime for computation and 1-2 minutes for plot rendering.
    #
    member_names = ds.coords['member_id'].values
    numEnsembleMembers = member_names.size

    numPlotsPerPage = 4
    numPages = np.ceil(numEnsembleMembers / numPlotsPerPage).astype(int)
    numPlotCols = 4

    figWidth = 25 
    figHeight = 12 #20

    pp = PdfPages(f'{plotdir}/{store_name}_maps.pdf')

    for pageNum in range(numPages):

        memberStart = pageNum * numPlotsPerPage
        memberEnd = np.min((memberStart + numPlotsPerPage, numEnsembleMembers))
        plot_row_index = 0

        # If this is the final page, target empty subplots for hiding.
        removeBlankSubplots = (pageNum == numPages-1) and (numEnsembleMembers < memberStart + numPlotsPerPage)

        # Plot the aggregate statistics across time.
        fig, axs = plt.subplots(numPlotsPerPage, numPlotCols, figsize=(figWidth, figHeight), constrained_layout=True)

        for index in np.arange(memberStart, memberEnd):

            mem_id = member_names[index]
            data_slice = getSlice(ds, data_var, mem_id)

            # Try loading the slice so it's read from disk only once.
            data_slice = data_slice.load()

            data_agg = data_slice.min(dim='time')
            plotMap(axs[plot_row_index, 0], data_agg, member_id=mem_id)

            data_agg = data_slice.max(dim='time')
            plotMap(axs[plot_row_index, 1], data_agg)

            data_agg = data_slice.mean(dim='time')
            plotMap(axs[plot_row_index, 2], data_agg)

            data_agg = data_slice.std(dim='time')
            plotMap(axs[plot_row_index, 3], data_agg)

            plot_row_index = plot_row_index + 1

        axs[0, 0].set_title(f'min({data_var})', fontsize=15)
        axs[0, 1].set_title(f'max({data_var})', fontsize=15)
        axs[0, 2].set_title(f'mean({data_var})', fontsize=15)
        axs[0, 3].set_title(f'std({data_var})', fontsize=15)

        if removeBlankSubplots:
            hide_subplots(axs, plot_row_index)

        plt.suptitle(store_name, fontsize=20)
        pp.savefig()
        plt.close()

    pp.close()

# %% [markdown]
# ### Create Time Series Plots over Multiple Pages
# These also mark the locations of missing values.

# %%
def plot_timeseries(ds, data_var, store_name, plotdir):
    # Generate plot. 
    #
    # With 30 workers, expect 1 minute walltime for computation and 1-2 minutes for plot rendering.
    #
    member_names = ds.coords['member_id'].values
    numEnsembleMembers = member_names.size

    numPlotsPerPage = 4
    numPages = np.ceil(numEnsembleMembers / numPlotsPerPage).astype(int)
    numPlotCols = 1

    figWidth = 25 
    figHeight = 20

    linewidth = 0.5

    pp = PdfPages(f'{plotdir}/{store_name}_ts.pdf')

    for pageNum in range(numPages):

        memberStart = pageNum * numPlotsPerPage
        memberEnd = np.min((memberStart + numPlotsPerPage, numEnsembleMembers))
        plot_row_index = 0
        
        # If this is the final page, target empty subplots for hiding.
        removeBlankSubplots = (pageNum == numPages-1) and (numEnsembleMembers < memberStart + numPlotsPerPage)

        # Plot the aggregate statistics across time.
        fig, axs = plt.subplots(numPlotsPerPage, numPlotCols, figsize=(figWidth, figHeight))

        print(f'Shape of subplots object: {axs.shape}')
        
        
        for index in np.arange(memberStart, memberEnd):

            mem_id = member_names[index]
            data_slice = getSlice(ds, data_var, mem_id)
            spatial_dims = getSpatialDimensionNames(data_slice)

            unit_string = ds[data_var].attrs['units']
            
            # Try loading the slice so it's read from disk only once.
            data_slice = data_slice.load()
            
            min_vals = data_slice.min(dim = spatial_dims)
            max_vals = data_slice.max(dim = spatial_dims)
            mean_vals = data_slice.mean(dim = spatial_dims)
            std_vals = data_slice.std(dim = spatial_dims)

            nan_indexes = np.isnan(min_vals)
            nan_times = ds.time[nan_indexes]

            axs[plot_row_index].plot(ds.time, max_vals, linewidth=linewidth, label='max', color='red')
            axs[plot_row_index].plot(ds.time, min_vals, linewidth=linewidth, label='min', color='blue')
            axs[plot_row_index].plot(ds.time, mean_vals, linewidth=linewidth, label='mean', color='black')
            axs[plot_row_index].fill_between(ds.time, (mean_vals - std_vals), (mean_vals + std_vals), color='grey', 
                         linewidth=0, label='std', alpha=0.5)
            
            ymin, ymax = axs[plot_row_index].get_ylim()
            rug_y = ymin + 0.01*(ymax-ymin)
            axs[plot_row_index].plot(nan_times, [rug_y]*len(nan_times), '|', color='m', label='missing')
            axs[plot_row_index].set_title(mem_id, fontsize=20)
            axs[plot_row_index].legend(loc='upper right')
            axs[plot_row_index].set_ylabel(unit_string)

            plot_row_index = plot_row_index + 1

        plt.suptitle(store_name, fontsize=25)
        plt.tight_layout(pad=10.2, w_pad=3.5, h_pad=3.5)
        
        if removeBlankSubplots:
            hide_subplots(axs, plot_row_index)
            
        pp.savefig()
        plt.close()
    pp.close()

# %% [markdown]
# #### Function Producing Maps of First, Middle, Last Timesteps

# %%
def getValidDateIndexes(member_slice):
    '''Search for the first and last dates with finite values.'''
    min_values = member_slice.min(dim = ['lat', 'lon'])
    is_finite = np.isfinite(min_values)
    finite_indexes = np.where(is_finite)
    start_index = finite_indexes[0][0]
    end_index = finite_indexes[0][-1]
    #print(f'start ={start_index}, end={end_index}')
    return start_index, end_index


def plot_first_mid_last(ds, data_var, store_name, plotdir):
    # Generate plot. 
    #
    # With 30 workers, expect 1 minute walltime for computation and 1-2 minutes for plot rendering.
    #
    member_names = ds.coords['member_id'].values
    numEnsembleMembers = member_names.size

    numPlotsPerPage = 4
    numPages = np.ceil(numEnsembleMembers / numPlotsPerPage).astype(int)
    numPlotCols = 3

    figWidth = 18 
    figHeight = 12 #20

    pp = PdfPages(f'{plotdir}/{store_name}_fml.pdf')

    for pageNum in range(numPages):

        memberStart = pageNum * numPlotsPerPage
        memberEnd = np.min((memberStart + numPlotsPerPage, numEnsembleMembers))
        plot_row_index = 0

        # If this is the final page, target empty subplots for hiding.
        removeBlankSubplots = (pageNum == numPages-1) and (numEnsembleMembers < memberStart + numPlotsPerPage)

        # Plot the aggregate statistics across time.
        fig, axs = plt.subplots(numPlotsPerPage, numPlotCols, figsize=(figWidth, figHeight), constrained_layout=True)

        for index in np.arange(memberStart, memberEnd):

            mem_id = member_names[index]
            data_slice = getSlice(ds, data_var, mem_id)
            
            start_index, end_index = getValidDateIndexes(data_slice)
            midDateIndex = np.floor(len(ds.time) / 2).astype(int)

            startDate = ds.time[start_index]
            first_step = data_slice.sel(time=startDate) 
            ax = axs[plot_row_index, 0]
            plotMap(ax, first_step, startDate, mem_id)

            midDate = ds.time[midDateIndex]
            mid_step = data_slice.sel(time=midDate)   
            ax = axs[plot_row_index, 1]
            plotMap(ax, mid_step, midDate)

            endDate = ds.time[end_index]
            last_step = data_slice.sel(time=endDate)            
            ax = axs[plot_row_index, 2]
            plotMap(ax, last_step, endDate)
            
            plot_row_index = plot_row_index + 1
 
        plt.suptitle(store_name, fontsize=20)

        if removeBlankSubplots:
            hide_subplots(axs, plot_row_index)
            
        pp.savefig()
        plt.close()

    pp.close()

# %% [markdown]
# ### Loop over Zarr Stores in Directory and Make Plots.

# %%
# For now, make the Zarr output directory a global variable.
#dirout = '/glade/scratch/bonnland/na-cordex/zarr-demo'
zarr_directory = '/glade/scratch/bonnland/DART/ds345.0/zarr-publish/'
plot_directory = '/glade/scratch/bonnland/DART/ds345.0/zarr-plots/'

p = Path(zarr_directory)
#stores = list(p.rglob("*.zarr"))
stores = list(p.rglob("HR.zarr"))
for store in stores:
    print(f'Opening {store}...')
    try:
        ds = xr.open_zarr(store.as_posix(), consolidated=True)
        print('\n')
    except Exception as e:
        print(e)
        continue
    data_vars = [vname for vname in ds.data_vars]
    data_var = data_vars[0]
    store_name = store.as_posix().split('/')[-1]
    
    # Only produce plots that haven't been created already.  
    plotdir = plot_directory + store_name
    if not os.path.exists(plotdir):
        os.makedirs(plotdir)
    else:
        # Plots exist; skip to the next case.
        #continue
        pass
    
    #plot_stat_maps(ds, data_var, store_name, plotdir)
    #plot_first_mid_last(ds, data_var, store_name, plotdir)
    plot_timeseries(ds, data_var, store_name, plotdir)
    
plt.show()
# Out:
# Opening /glade/scratch/bonnland/DART/ds345.0/zarr-publish/HR.zarr...
#
#
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)
# Shape of subplots object: (4,)

# %% [markdown]
# ### Release the workers.

# %%
# !date
# Out:
# Tue Jul 20 18:00:32 MDT 2021

# %%
# !qstat -u bonnland
# Out:
# Job id            Name             User              Time Use S Queue
# ----------------  ---------------- ----------------  -------- - -----
# 8634095.chadmin1  st_archive.FCnu  tilmes                   0 H shareex
# 8645149.chadmin1  f.e21.B1850.f09  ranfeng                  0 H shareex
# 8658478.chadmin1  f.e21.B1850.f09  ranfeng                  0 H shareex
# 8663535.chadmin1  st_archive.FWma  nadavis                  0 H shareex
# 8675323.chadmin1  f.e21.B1850.f09  ranfeng                  0 H shareex
# 8675561.chadmin1  f.e21.B1850.f09  ranfeng                  0 H shareex
# 8675724.chadmin1  f.e21.B1850.f09  ranfeng                  0 H shareex
# 8795079.chadmin1  Test2.st_archiv  lzastko                  0 H shareex
# 8848196.chadmin1  st_archive.f.e2  nadavis                  0 H shareex
# 8848305.chadmin1  st_archive.b.e2  nadavis                  0 H shareex
# 9007934.chadmin1  st_archive.one_  mohsinn                  0 H shareex
# 9012951.chadmin1  st_archive.b.e2  nadavis                  0 H shareex
# 9027582.chadmin1  st_archive.f.e2  nadavis                  0 H shareex
# 9198270.chadmin1  st_archive.CESM  crtabor                  0 H shareex
# 9202142.chadmin1  st_archive.FWma  nadavis                  0 H shareex
# 9227911.chadmin1  b.e21.B1850.f09  whokim                   0 H shareex
# 9227933.chadmin1  b.e21.B1850.f09  whokim                   0 H shareex
# 9227974.chadmin1  b.e21.B1850.f09  whokim                   0 H shareex
# 9275655.chadmin1  st_archive.ETP.  altuntas                 0 H shareex
# 9294864.chadmin1  st_archive.b.e2  raymonds                 0 H shareex
# 9320443.chadmin1  st_archive.g.e2  altuntas                 0 H shareex
# 9389243.chadmin1  st_archive.f.e2  nadavis                  0 H shareex
# 9417826.chadmin1  st_archive.bg.e  aleahs                   0 H shareex
# 9424311.chadmin1  st_archive.b.e2  raymonds                 0 H shareex
# 9474351.chadmin1  st_archive.FCnu  tilmes                   0 H shareex
# 9536945.chadmin1  st_archive.fx20  liuh                     0 H shareex
# 9538058.chadmin1  st_archive.b.e2  islas                    0 H shareex
# 9538454.chadmin1  b.e21.B1850.f09  ranfeng                  0 H shareex
# 9540317.chadmin1  st_archive.cesm  aherring                 0 H shareex
# 9542023.chadmin1  st_archive.PR_c  wenfut                   0 H shareex
# 9542054.chadmin1  st_archive.PR_c  wenfut                   0 H shareex
# 9543496.chadmin1  st_archive.f.wa  joemci                   0 H shareex
# 9548258.chadmin1  st_archive.b.re  joemci                   0 H shareex
# 9548876.chadmin1  st_archive.b.e2  duvivier                 0 H shareex
# 9548993.chadmin1  st_archive.b.e2  duvivier                 0 H shareex
# 9549294.chadmin1  st_archive.b.e2  duvivier                 0 H shareex
# 9549719.chadmin1  st_archive.b.e2  duvivier                 0 H shareex
# 9549881.chadmin1  st_archive.b.e2  duvivier                 0 H shareex
# 9549937.chadmin1  test2.st_archiv  wanghao                  0 H shareex
# 9550040.chadmin1  st_archive.b.e2  geostrat                 0 H shareex
# 9550071.chadmin1  TSMLT10          geostrat                 0 H shareex
# 9550119.chadmin1  st_archive.b.e2  geostrat                 0 H shareex
# 9550133.chadmin1  st_archive.b.e2  geostrat                 0 H shareex
# 9550144.chadmin1  st_archive.b.e2  geostrat                 0 H shareex
# 9550908.chadmin1  st_archive.coup  czarakas                 0 H shareex
# 9550925.chadmin1  st_archive.coup  czarakas                 0 H shareex
# 9550926.chadmin1  topo_regen.bg.e  aleahs                   0 H shareex
# 9550929.chadmin1  st_archive.bg.e  aleahs                   0 H shareex
# 9551824.chadmin1  st_archive.f.re  joemci                   0 H shareex
# 9552282.chadmin1  st_archive.f.wa  joemci                   0 H shareex
# 9552511.chadmin1  st_archive.b.e2  sbradley                 0 H shareex
# 9552658.chadmin1  PCA_extract      kjfuller          05:49:40 R shareex
# 9552820.chadmin1  st_archive.b.e2  sledd                    0 H shareex
# 9553026.chadmin1  st_archive.b.e2  dbailey                  0 H shareex
# 9554279.chadmin1  st_archive.b.e2  sbradley                 0 H shareex
# 9554295.chadmin1  st_archive.High  hansi                    0 H shareex
# 9554741.chadmin1  st_archive.LowP  hansi                    0 H shareex
# 9554874.chadmin1  st_archive.High  hansi                    0 H shareex
# 9554928.chadmin1  st_archive.LowH  hansi                    0 H shareex
# 9556003.chadmin1  st_archive.f.wa  joemci                   0 H shareex
# 9556132.chadmin1  b.e21.T31_g37.a  pdinezio                 0 H shareex
# 9557208.chadmin1  addhtg1986.st_a  debdas                   0 H shareex
# 9558357.chadmin1  st_archive.ETP.  bachman                  0 H shareex
# 9558513.chadmin1  ee12             cesmsf                   0 H shareex
# 9559086.chadmin1  st_archive.b.e2  cesmsf                   0 H shareex
# 9559087.chadmin1  yr2000.cntl      nanr                     0 H shareex
# 9559386.chadmin1  st_archive.b.e2  cesmsf                   0 H shareex
# 9559489.chadmin1  run.NEON_OSBS    negins            02:10:58 R shareex
# 9559503.chadmin1  st_archive.NEON  negins                   0 H shareex
# 9559588.chadmin1  st_archive.b.e2  sledd                    0 H shareex
# 9559591.chadmin1  st_archive.b.e2  cesmsf                   0 H shareex
# 9559594.chadmin1  ee15             cesmsf                   0 H shareex
# 9559599.chadmin1  st_archive.b.e2  cesmsf                   0 H shareex
# 9559600.chadmin1  ee11             cesmsf                   0 H shareex
# 9559601.chadmin1  ee13             cesmsf                   0 H shareex
# 9559611.chadmin1  st_archive.b.e2  cesmsf                   0 H shareex
# 9559618.chadmin1  st_archive.md.B  kmcmonigal               0 H shareex
# 9559619.chadmin1  st_archive.md.B  kmcmonigal               0 H shareex
# 9559622.chadmin1  st_archive.md.B  kmcmonigal               0 H shareex
# 9559623.chadmin1  st_archive.md.B  kmcmonigal               0 H shareex
# 9559624.chadmin1  st_archive.md.B  kmcmonigal               0 H shareex
# 9559625.chadmin1  ee14             cesmsf                   0 H shareex
# 9559629.chadmin1  st_archive.md.B  kmcmonigal               0 H shareex
# 9559633.chadmin1  st_archive.PR3h  wenfut                   0 H shareex
# 9559826.chadmin1  st_archive.clm5  oleson                   0 H shareex
# 9559865.chadmin1  jhchbatch        dlawren           00:00:54 R shareex
# 9559925.chadmin1  st_archive.PR3h  wenfut                   0 H shareex
# 9559933.chadmin1  st_archive.PR3h  wenfut                   0 H shareex
# 9559941.chadmin1  st_archive.PR3h  wenfut                   0 H shareex
# 9559950.chadmin1  st_archive.PR3h  wenfut                   0 H shareex
# 9560097.chadmin1  st_archive.ne60  nickp                    0 H shareex
# 9561966.chadmin1  run.NEON_OSBS_s  negins            00:32:06 R shareex
# 9561973.chadmin1  st_archive.NEON  negins                   0 H shareex
# 9562278.chadmin1  st_archive.cam6  aherring                 0 H shareex
# 9562440.chadmin1  st_archive.futu  jscheff                  0 H shareex
# 9562759.chadmin1  I1850CLM50_001.  negins                   0 H shareex
# 9562801.chadmin1  st_archive.FCnu  tilmes                   0 H shareex
# 9563104.chadmin1  st_archive.PPE_  trude                    0 H shareex
# 9563148.chadmin1  st_archive.PPE_  trude                    0 H shareex
# 9563196.chadmin1  st_archive.PPE_  trude                    0 H shareex
# 9144157.chadmin1  oneway           ampsrt            00:00:00 H ampsrt
# 9148309.chadmin1  Post             jimenez           00:00:00 H premium
# 9199821.chadmin1  Post             jimenez           00:00:00 H premium
# 9214737.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9224670.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9231530.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9238754.chadmin1  Geogrid          jimenez           00:00:00 H premium
# 9238760.chadmin1  Metgrid          jimenez                  0 H premium
# 9238764.chadmin1  Real             jimenez                  0 H premium
# 9238767.chadmin1  WRF              jimenez                  0 H regular
# 9238770.chadmin1  Post             jimenez                  0 H premium
# 9238786.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9238793.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9238834.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9238855.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9238864.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9238972.chadmin1  Real             jimenez           00:00:00 H premium
# 9238975.chadmin1  WRF              jimenez                  0 H regular
# 9238979.chadmin1  Post             jimenez                  0 H premium
# 9253965.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9262012.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9262015.chadmin1  AR_hindcast      dikpati           00:00:00 H premium
# 9412193.chadmin1  st_archive.ndgb  ckruse                   0 H premium
# 9431503.chadmin1  conus-merra      sbuckhol                 0 H regular
# 9431504.chadmin1  conus-merra      sbuckhol                 0 H regular
# 9464312.chadmin1  conus-merra      sbuckhol                 0 H regular
# 9536821.chadmin1  cmaq             rkumar                   0 Q economy
# 9536822.chadmin1  gsi              rkumar                   0 H economy
# 9536823.chadmin1  cmaq             rkumar                   0 H economy
# 9536824.chadmin1  gsi              rkumar                   0 H economy
# 9536825.chadmin1  gsi              rkumar                   0 H economy
# 9536826.chadmin1  cmaq             rkumar                   0 H economy
# 9536827.chadmin1  gsi              rkumar                   0 H economy
# 9536828.chadmin1  cmaq             rkumar                   0 H economy
# 9536829.chadmin1  cmaq             rkumar                   0 H economy
# 9536830.chadmin1  gsi              rkumar                   0 H economy
# 9536831.chadmin1  cmaq             rkumar                   0 H economy
# 9536832.chadmin1  gsi              rkumar                   0 H economy
# 9536833.chadmin1  gsi              rkumar                   0 H economy
# 9536834.chadmin1  cmaq             rkumar                   0 H economy
# 9536835.chadmin1  gsi              rkumar                   0 H economy
# 9536836.chadmin1  cmaq             rkumar                   0 H economy
# 9536837.chadmin1  cmaq             rkumar                   0 H economy
# 9536838.chadmin1  gsi              rkumar                   0 H economy
# 9536839.chadmin1  cmaq             rkumar                   0 H economy
# 9536840.chadmin1  gsi              rkumar                   0 H economy
# 9536841.chadmin1  gsi              rkumar                   0 H economy
# 9536842.chadmin1  cmaq             rkumar                   0 H economy
# 9536843.chadmin1  gsi              rkumar                   0 H economy
# 9536844.chadmin1  cmaq             rkumar                   0 H economy
# 9536846.chadmin1  cmaq             rkumar                   0 H economy
# 9536849.chadmin1  gsi              rkumar                   0 H economy
# 9536850.chadmin1  cmaq             rkumar                   0 H economy
# 9536851.chadmin1  gsi              rkumar                   0 H economy
# 9536852.chadmin1  gsi              rkumar                   0 H economy
# 9536854.chadmin1  cmaq             rkumar                   0 H economy
# 9536856.chadmin1  gsi              rkumar                   0 H economy
# 9536858.chadmin1  cmaq             rkumar                   0 H economy
# 9536859.chadmin1  cmaq             rkumar                   0 H economy
# 9536860.chadmin1  gsi              rkumar                   0 H economy
# 9536861.chadmin1  cmaq             rkumar                   0 H economy
# 9536862.chadmin1  gsi              rkumar                   0 H economy
# 9536863.chadmin1  gsi              rkumar                   0 H economy
# 9536864.chadmin1  cmaq             rkumar                   0 H economy
# 9536865.chadmin1  gsi              rkumar                   0 H economy
# 9536866.chadmin1  cmaq             rkumar                   0 H economy
# 9536867.chadmin1  cmaq             rkumar                   0 H economy
# 9536868.chadmin1  gsi              rkumar                   0 H economy
# 9536869.chadmin1  cmaq             rkumar                   0 H economy
# 9536870.chadmin1  gsi              rkumar                   0 H economy
# 9536871.chadmin1  gsi              rkumar                   0 H economy
# 9536872.chadmin1  cmaq             rkumar                   0 H economy
# 9536874.chadmin1  gsi              rkumar                   0 H economy
# 9536875.chadmin1  cmaq             rkumar                   0 H economy
# 9536877.chadmin1  cmaq             rkumar                   0 H economy
# 9536879.chadmin1  gsi              rkumar                   0 H economy
# 9536880.chadmin1  cmaq             rkumar                   0 H economy
# 9536881.chadmin1  gsi              rkumar                   0 H economy
# 9536882.chadmin1  gsi              rkumar                   0 H economy
# 9536885.chadmin1  cmaq             rkumar                   0 H economy
# 9536888.chadmin1  gsi              rkumar                   0 H economy
# 9536891.chadmin1  cmaq             rkumar                   0 H economy
# 9536893.chadmin1  cmaq             rkumar                   0 H economy
# 9536894.chadmin1  gsi              rkumar                   0 H economy
# 9536895.chadmin1  cmaq             rkumar                   0 H economy
# 9536896.chadmin1  gsi              rkumar                   0 H economy
# 9536897.chadmin1  gsi              rkumar                   0 H economy
# 9536898.chadmin1  cmaq             rkumar                   0 H economy
# 9536899.chadmin1  gsi              rkumar                   0 H economy
# 9536900.chadmin1  cmaq             rkumar                   0 H economy
# 9536901.chadmin1  cmaq             rkumar                   0 H economy
# 9536903.chadmin1  gsi              rkumar                   0 H economy
# 9536904.chadmin1  cmaq             rkumar                   0 H economy
# 9536905.chadmin1  gsi              rkumar                   0 H economy
# 9536906.chadmin1  gsi              rkumar                   0 H economy
# 9536908.chadmin1  cmaq             rkumar                   0 H economy
# 9536910.chadmin1  gsi              rkumar                   0 H economy
# 9536913.chadmin1  cmaq             rkumar                   0 H economy
# 9536914.chadmin1  cmaq             rkumar                   0 H economy
# 9536915.chadmin1  gsi              rkumar                   0 H economy
# 9536916.chadmin1  cmaq             rkumar                   0 H economy
# 9536917.chadmin1  gsi              rkumar                   0 H economy
# 9536918.chadmin1  gsi              rkumar                   0 H economy
# 9536919.chadmin1  cmaq             rkumar                   0 H economy
# 9536921.chadmin1  gsi              rkumar                   0 H economy
# 9536922.chadmin1  cmaq             rkumar                   0 H economy
# 9536923.chadmin1  cmaq             rkumar                   0 H economy
# 9536924.chadmin1  gsi              rkumar                   0 H economy
# 9536925.chadmin1  cmaq             rkumar                   0 H economy
# 9536926.chadmin1  gsi              rkumar                   0 H economy
# 9536927.chadmin1  gsi              rkumar                   0 H economy
# 9536928.chadmin1  cmaq             rkumar                   0 H economy
# 9536929.chadmin1  gsi              rkumar                   0 H economy
# 9536930.chadmin1  cmaq             rkumar                   0 H economy
# 9536931.chadmin1  cmaq             rkumar                   0 H economy
# 9536932.chadmin1  gsi              rkumar                   0 H economy
# 9536933.chadmin1  cmaq             rkumar                   0 H economy
# 9536934.chadmin1  gsi              rkumar                   0 H economy
# 9536935.chadmin1  gsi              rkumar                   0 H economy
# 9536939.chadmin1  cmaq             rkumar                   0 H economy
# 9536942.chadmin1  gsi              rkumar                   0 H economy
# 9536943.chadmin1  run.fx2000_ne12  liuh                     0 Q economy
# 9536944.chadmin1  cmaq             rkumar                   0 H economy
# 9536946.chadmin1  cmaq             rkumar                   0 H economy
# 9536948.chadmin1  gsi              rkumar                   0 H economy
# 9536950.chadmin1  cmaq             rkumar                   0 H economy
# 9536952.chadmin1  gsi              rkumar                   0 H economy
# 9536953.chadmin1  gsi              rkumar                   0 H economy
# 9536954.chadmin1  cmaq             rkumar                   0 H economy
# 9536955.chadmin1  gsi              rkumar                   0 H economy
# 9536956.chadmin1  cmaq             rkumar                   0 H economy
# 9536957.chadmin1  cmaq             rkumar                   0 H economy
# 9536958.chadmin1  gsi              rkumar                   0 H economy
# 9536959.chadmin1  cmaq             rkumar                   0 H economy
# 9536960.chadmin1  gsi              rkumar                   0 H economy
# 9536961.chadmin1  gsi              rkumar                   0 H economy
# 9536963.chadmin1  cmaq             rkumar                   0 H economy
# 9536965.chadmin1  gsi              rkumar                   0 H economy
# 9536967.chadmin1  cmaq             rkumar                   0 H economy
# 9538196.chadmin1  run3_mbr13.1987  sglanvil                 0 Q economy
# 9538197.chadmin1  run3_mbr20.1987  sglanvil                 0 Q economy
# 9538198.chadmin1  run3_mbr14.1987  sglanvil                 0 Q economy
# 9538199.chadmin1  run3_mbr15.1987  sglanvil                 0 Q economy
# 9538200.chadmin1  run3_mbr16.1987  sglanvil                 0 Q economy
# 9538202.chadmin1  run3_mbr17.1987  sglanvil                 0 Q economy
# 9538203.chadmin1  run3_mbr18.1987  sglanvil                 0 Q economy
# 9538212.chadmin1  run2_mbr15.1986  sglanvil                 0 Q economy
# 9538213.chadmin1  run2_mbr16.1986  sglanvil                 0 Q economy
# 9538214.chadmin1  run2_mbr17.1986  sglanvil                 0 Q economy
# 9538215.chadmin1  run2_mbr18.1986  sglanvil                 0 Q economy
# 9538217.chadmin1  run2_mbr19.1986  sglanvil                 0 Q economy
# 9538218.chadmin1  run2_mbr20.1986  sglanvil                 0 Q economy
# 9538219.chadmin1  run3_mbr11.1986  sglanvil                 0 Q economy
# 9538220.chadmin1  run3_mbr12.1986  sglanvil                 0 Q economy
# 9538221.chadmin1  run3_mbr13.1986  sglanvil                 0 Q economy
# 9538222.chadmin1  run3_mbr14.1986  sglanvil                 0 Q economy
# 9538453.chadmin1  b.e21.B1850.f09  ranfeng                  0 Q economy
# 9540312.chadmin1  run.cesm2_2_alp  aherring                 0 Q regular
# 9540365.chadmin1  dassH            jeffreyg          3865:45: R regular
# 9540691.chadmin1  run.f.e21.FWscH  hannay                   0 Q regular
# 9540694.chadmin1  st_archive.f.e2  hannay                   0 H regular
# 9540910.chadmin1  iCEN_B1850C5CN_  emilydo                  0 Q economy
# 9542167.chadmin1  run1_mbr11.1985  sglanvil                 0 Q economy
# 9542168.chadmin1  run1_mbr12.1985  sglanvil                 0 Q economy
# 9542169.chadmin1  run1_mbr13.1985  sglanvil                 0 Q economy
# 9542170.chadmin1  run1_mbr14.1985  sglanvil                 0 Q economy
# 9542172.chadmin1  run1_mbr15.1985  sglanvil                 0 Q economy
# 9542173.chadmin1  run1_mbr16.1985  sglanvil                 0 Q economy
# 9542174.chadmin1  run1_mbr17.1985  sglanvil                 0 Q economy
# 9542175.chadmin1  run1_mbr18.1985  sglanvil                 0 Q economy
# 9542176.chadmin1  run1_mbr19.1985  sglanvil                 0 Q economy
# 9542177.chadmin1  run1_mbr20.1985  sglanvil                 0 Q economy
# 9542183.chadmin1  run1_mbr11.1984  sglanvil                 0 Q economy
# 9542184.chadmin1  run1_mbr12.1984  sglanvil                 0 Q economy
# 9542185.chadmin1  run1_mbr13.1984  sglanvil                 0 Q economy
# 9542186.chadmin1  run1_mbr14.1984  sglanvil                 0 Q economy
# 9542187.chadmin1  run1_mbr15.1984  sglanvil                 0 Q economy
# 9542188.chadmin1  run1_mbr16.1984  sglanvil                 0 Q economy
# 9542190.chadmin1  run1_mbr17.1984  sglanvil                 0 Q economy
# 9542191.chadmin1  run1_mbr18.1984  sglanvil                 0 Q economy
# 9542192.chadmin1  run1_mbr19.1984  sglanvil                 0 Q economy
# 9542193.chadmin1  run1_mbr20.1984  sglanvil                 0 Q economy
# 9542199.chadmin1  run1_mbr11.1983  sglanvil                 0 Q economy
# 9542201.chadmin1  run1_mbr12.1983  sglanvil                 0 Q economy
# 9542202.chadmin1  run1_mbr13.1983  sglanvil                 0 Q economy
# 9542203.chadmin1  run1_mbr14.1983  sglanvil                 0 Q economy
# 9542204.chadmin1  run1_mbr15.1983  sglanvil                 0 Q economy
# 9542205.chadmin1  run1_mbr16.1983  sglanvil                 0 Q economy
# 9542206.chadmin1  run1_mbr17.1983  sglanvil                 0 Q economy
# 9542207.chadmin1  run1_mbr18.1983  sglanvil                 0 Q economy
# 9542208.chadmin1  run1_mbr19.1983  sglanvil                 0 Q economy
# 9542209.chadmin1  run1_mbr20.1983  sglanvil                 0 Q economy
# 9542218.chadmin1  run1_mbr11.1982  sglanvil                 0 Q economy
# 9542221.chadmin1  run1_mbr12.1982  sglanvil                 0 Q economy
# 9542222.chadmin1  run1_mbr13.1982  sglanvil                 0 Q economy
# 9542223.chadmin1  run1_mbr14.1982  sglanvil                 0 Q economy
# 9542224.chadmin1  run1_mbr15.1982  sglanvil                 0 Q economy
# 9542225.chadmin1  run1_mbr16.1982  sglanvil                 0 Q economy
# 9542226.chadmin1  run1_mbr17.1982  sglanvil                 0 Q economy
# 9542227.chadmin1  run1_mbr18.1982  sglanvil                 0 Q economy
# 9542228.chadmin1  run1_mbr19.1982  sglanvil                 0 Q economy
# 9542229.chadmin1  run1_mbr20.1982  sglanvil                 0 Q economy
# 9542242.chadmin1  run1_mbr11.1981  sglanvil                 0 Q economy
# 9542243.chadmin1  run1_mbr12.1981  sglanvil                 0 Q economy
# 9542244.chadmin1  run1_mbr13.1981  sglanvil                 0 Q economy
# 9542245.chadmin1  run1_mbr14.1981  sglanvil                 0 Q economy
# 9542246.chadmin1  run1_mbr15.1981  sglanvil                 0 Q economy
# 9542247.chadmin1  run1_mbr16.1981  sglanvil                 0 Q economy
# 9542248.chadmin1  run1_mbr17.1981  sglanvil                 0 Q economy
# 9542249.chadmin1  run1_mbr18.1981  sglanvil                 0 Q economy
# 9542251.chadmin1  run1_mbr19.1981  sglanvil                 0 Q economy
# 9542252.chadmin1  run1_mbr20.1981  sglanvil                 0 Q economy
# 9542258.chadmin1  run1_mbr11.1980  sglanvil                 0 Q economy
# 9542259.chadmin1  run1_mbr12.1980  sglanvil                 0 Q economy
# 9542260.chadmin1  run1_mbr13.1980  sglanvil                 0 Q economy
# 9542261.chadmin1  run1_mbr14.1980  sglanvil                 0 Q economy
# 9542262.chadmin1  run1_mbr15.1980  sglanvil                 0 Q economy
# 9542263.chadmin1  run1_mbr16.1980  sglanvil                 0 Q economy
# 9542264.chadmin1  run1_mbr17.1980  sglanvil                 0 Q economy
# 9542265.chadmin1  run1_mbr18.1980  sglanvil                 0 Q economy
# 9542266.chadmin1  run1_mbr19.1980  sglanvil                 0 Q economy
# 9542267.chadmin1  run1_mbr20.1980  sglanvil                 0 Q economy
# 9545870.chadmin1  mpi_job          cenlinhe                 0 Q economy
# 9546999.chadmin1  cmaq             rkumar                   0 Q economy
# 9547000.chadmin1  cmaq             rkumar                   0 H economy
# 9547001.chadmin1  cmaq             rkumar                   0 H economy
# 9547002.chadmin1  cmaq             rkumar                   0 H economy
# 9547003.chadmin1  cmaq             rkumar                   0 H economy
# 9547004.chadmin1  cmaq             rkumar                   0 H economy
# 9547006.chadmin1  cmaq             rkumar                   0 H economy
# 9547007.chadmin1  cmaq             rkumar                   0 H economy
# 9547008.chadmin1  cmaq             rkumar                   0 H economy
# 9547009.chadmin1  cmaq             rkumar                   0 H economy
# 9547010.chadmin1  cmaq             rkumar                   0 H economy
# 9547011.chadmin1  cmaq             rkumar                   0 H economy
# 9547012.chadmin1  cmaq             rkumar                   0 H economy
# 9547013.chadmin1  cmaq             rkumar                   0 H economy
# 9547017.chadmin1  cmaq             rkumar                   0 H economy
# 9547019.chadmin1  cmaq             rkumar                   0 H economy
# 9547021.chadmin1  cmaq             rkumar                   0 H economy
# 9547023.chadmin1  cmaq             rkumar                   0 H economy
# 9547024.chadmin1  cmaq             rkumar                   0 H economy
# 9547025.chadmin1  cmaq             rkumar                   0 H economy
# 9547026.chadmin1  cmaq             rkumar                   0 H economy
# 9547027.chadmin1  cmaq             rkumar                   0 H economy
# 9547952.chadmin1  WCG_2_10         arezoo            72:32:39 R regular
# 9547956.chadmin1  mup5L10          farsoiya          2126:30: R regular
# 9547966.chadmin1  WCG_3_13         arezoo            35:26:06 R regular
# 9548016.chadmin1  WCG_11_14        arezoo            159:30:0 R regular
# 9548019.chadmin1  WCG_102_4        mazrooei          171:08:0 R regular
# 9548023.chadmin1  WCG_5_18         arezoo            118:06:3 R regular
# 9548025.chadmin1  WCG_13_14        arezoo            158:52:2 R regular
# 9548031.chadmin1  WCG_6_3          arezoo            278:11:1 R regular
# 9548074.chadmin1  WCG_2_11         arezoo            281:27:1 R regular
# 9548094.chadmin1  runwrf           stepheba          1091:10: R regular
# 9548099.chadmin1  WCG_103_1        mazrooei          176:58:4 R regular
# 9548130.chadmin1  run.g.e22.GMOM_  jessicak                 0 Q economy
# 9548133.chadmin1  st_archive.g.e2  jessicak                 0 H economy
# 9548137.chadmin1  gr_160wR         sciola            2203:29: R economy
# 9548187.chadmin1  run.g.e22.GMOM_  jessicak                 0 Q economy
# 9548188.chadmin1  st_archive.g.e2  jessicak                 0 H economy
# 9548240.chadmin1  WCG_11_15        arezoo            150:12:3 R regular
# 9548243.chadmin1  WCG_102_5        mazrooei          229:11:2 R regular
# 9548244.chadmin1  WCG_5_0          arezoo            178:01:3 R regular
# 9548246.chadmin1  WCG_6_4          arezoo            267:34:0 R regular
# 9548257.chadmin1  run.b.release-c  joemci            3118:45: R economy
# 9548262.chadmin1  WCG_2_12         arezoo            284:27:3 R regular
# 9548293.chadmin1  rar1.15.2.0      chepurin          2036:23: R regular
# 9548320.chadmin1  WCG_11_16        arezoo            143:26:2 R regular
# 9548321.chadmin1  WCG_102_6        mazrooei          149:16:2 R regular
# 9548323.chadmin1  WCG_13_16        arezoo            140:09:3 R regular
# 9548324.chadmin1  WCG_5_1          arezoo            176:44:5 R regular
# 9548325.chadmin1  WCG_6_5          arezoo            249:13:0 R regular
# 9548347.chadmin1  WCG_2_13         arezoo            152:10:4 R regular
# 9548849.chadmin1  AR_hindcast      dikpati           182:50:2 R premium
# 9548875.chadmin1  run.b.e21.BSSP3  duvivier          6911:16: R regular
# 9548904.chadmin1  AR_hindcast      dikpati           181:03:4 R premium
# 9548913.chadmin1  WCG_11_17        arezoo            136:09:2 R regular
# 9548919.chadmin1  WCG_102_7        mazrooei          202:53:0 R regular
# 9548930.chadmin1  WCG_13_17        arezoo            136:45:4 R regular
# 9548934.chadmin1  AR_hindcast      dikpati           180:30:2 R premium
# 9548951.chadmin1  WCG_6_6          arezoo            231:21:4 R regular
# 9548955.chadmin1  run.cam6_2_038_  wijngaard                0 Q economy
# 9548991.chadmin1  run.b.e21.BSSP3  duvivier          6815:45: R regular
# 9549029.chadmin1  WRF_01           bwallace          1069:34: R economy
# 9549059.chadmin1  AR_hindcast      dikpati           178:32:3 R premium
# 9549125.chadmin1  AR_hindcast      dikpati           177:26:3 R premium
# 9549129.chadmin1  AR_hindcast      dikpati           177:21:4 R premium
# 9549133.chadmin1  AR_hindcast_hi   dikpati           176:52:2 R regular
# 9549148.chadmin1  AR_hindcast_hi   dikpati           176:16:4 R regular
# 9549150.chadmin1  AR_hindcast_hi   dikpati           176:12:1 R regular
# 9549156.chadmin1  AR_hindcast      dikpati           175:34:1 R premium
# 9549157.chadmin1  AR_hindcast      dikpati           175:36:4 R premium
# 9549165.chadmin1  AR_hindcast      dikpati           175:03:0 R premium
# 9549166.chadmin1  AR_hindcast_hi   dikpati           175:02:1 R regular
# 9549167.chadmin1  AR_hindcast_hi   dikpati           174:27:4 R regular
# 9549169.chadmin1  AR_hindcast      dikpati           174:21:1 R premium
# 9549181.chadmin1  AR_hindcast      dikpati           173:54:3 R premium
# 9549182.chadmin1  les_tank_nond    nylah             2148:30: R regular
# 9549185.chadmin1  AR_hindcast      dikpati           173:47:0 R premium
# 9549188.chadmin1  AR_hindcast      dikpati           173:49:0 R premium
# 9549205.chadmin1  run.cam6_2_038_  wijngaard                0 Q economy
# 9549217.chadmin1  WCG_11_18        arezoo            64:45:44 R regular
# 9549218.chadmin1  run.cam6_2_038_  wijngaard                0 Q economy
# 9549219.chadmin1  WCG_102_8        mazrooei          205:42:2 R regular
# 9549226.chadmin1  WCG_13_18        arezoo            65:28:36 R regular
# 9549271.chadmin1  AR_hindcast      dikpati           171:27:3 R premium
# 9549288.chadmin1  AR_hindcast      dikpati           170:44:2 R premium
# 9549293.chadmin1  run.b.e21.BSSP3  duvivier          6765:46: R regular
# 9549295.chadmin1  AR_hindcast      dikpati           170:52:0 R premium
# 9549300.chadmin1  AR_hindcast_hi   dikpati           170:47:4 R regular
# 9549301.chadmin1  wrf_SA           dominguz                 0 Q economy
# 9549306.chadmin1  wa6_noCAA_b_ic2  gus                      0 Q regular
# 9549307.chadmin1  wa6_noCAA_b_ic2  gus                      0 H regular
# 9549316.chadmin1  AR_hindcast      dikpati           170:05:0 R premium
# 9549319.chadmin1  AR_hindcast      dikpati           169:37:2 R premium
# 9549327.chadmin1  AR_hindcast      dikpati           169:36:2 R premium
# 9549345.chadmin1  AR_hindcast      dikpati           169:00:1 R premium
# 9549634.chadmin1  AR_hindcast      dikpati           166:40:1 R premium
# 9549640.chadmin1  wa6_noCAA_b_ic3  gus                      0 Q regular
# 9549657.chadmin1  AR_hindcast_hi   dikpati           166:36:5 R regular
# 9549664.chadmin1  AR_hindcast      dikpati           166:38:2 R premium
# 9549665.chadmin1  AR_hindcast_hi   dikpati           166:40:3 R regular
# 9549668.chadmin1  wa6_noCAA_b_ic3  gus                      0 H regular
# 9549669.chadmin1  AR_hindcast      dikpati           166:36:2 R premium
# 9549673.chadmin1  AR_hindcast      dikpati           166:37:3 R premium
# 9549708.chadmin1  AR_hindcast_hi   dikpati           165:57:0 R regular
# 9549710.chadmin1  AR_hindcast_hi   dikpati           165:57:0 R regular
# 9549714.chadmin1  run.b.e21.BSSP3  duvivier          6595:36: R regular
# 9549715.chadmin1  AR_hindcast_hi   dikpati           165:57:1 R regular
# 9549736.chadmin1  AR_hindcast      dikpati           165:58:5 R premium
# 9549747.chadmin1  AR_hindcast      dikpati           166:01:2 R premium
# 9549748.chadmin1  AR_hindcast      dikpati           165:59:5 R premium
# 9549755.chadmin1  run.h2.sd.001    lamar             9964:35: R regular
# 9549756.chadmin1  st_archive.h2.s  lamar                    0 H regular
# 9549757.chadmin1  run.h2.sd.002    lamar             9753:51: R regular
# 9549758.chadmin1  st_archive.h2.s  lamar                    0 H regular
# 9549759.chadmin1  run.h2.sd.003    lamar             9647:13: R regular
# 9549760.chadmin1  st_archive.h2.s  lamar                    0 H regular
# 9549779.chadmin1  run4_mbr11.1989  sglanvil                 0 Q economy
# 9549783.chadmin1  run4_mbr12.1989  sglanvil                 0 Q economy
# 9549784.chadmin1  run4_mbr13.1989  sglanvil                 0 Q economy
# 9549785.chadmin1  run4_mbr14.1989  sglanvil                 0 Q economy
# 9549786.chadmin1  run4_mbr15.1989  sglanvil                 0 Q economy
# 9549787.chadmin1  run4_mbr16.1989  sglanvil                 0 Q economy
# 9549788.chadmin1  run4_mbr17.1989  sglanvil                 0 Q economy
# 9549789.chadmin1  run4_mbr18.1989  sglanvil                 0 Q economy
# 9549790.chadmin1  run4_mbr19.1989  sglanvil                 0 Q economy
# 9549791.chadmin1  run4_mbr20.1989  sglanvil                 0 Q economy
# 9549797.chadmin1  AR_hindcast      dikpati           164:11:0 R premium
# 9549805.chadmin1  AR_hindcast      dikpati           164:08:1 R premium
# 9549806.chadmin1  AR_hindcast_hi   dikpati           163:32:5 R regular
# 9549813.chadmin1  WCG_11_0         arezoo            119:06:5 R regular
# 9549820.chadmin1  AR_hindcast      dikpati           162:19:1 R premium
# 9549821.chadmin1  WCG_13_0         arezoo            120:22:5 R regular
# 9549830.chadmin1  AR_hindcast_hi   dikpati           162:20:0 R regular
# 9549831.chadmin1  AR_hindcast_hi   dikpati           162:18:0 R regular
# 9549833.chadmin1  AR_hindcast      dikpati           162:18:4 R premium
# 9549841.chadmin1  WCG_27_2         xfeng             311:33:1 R regular
# 9549843.chadmin1  AR_hindcast      dikpati           161:48:5 R premium
# 9549853.chadmin1  AR_hindcast_hi   dikpati           161:10:2 R regular
# 9549856.chadmin1  AR_hindcast_hi   dikpati           161:10:5 R regular
# 9549857.chadmin1  WCG_28_0         xfeng             313:59:1 R regular
# 9549863.chadmin1  AR_hindcast      dikpati           160:33:0 R premium
# 9549864.chadmin1  AR_hindcast_hi   dikpati           160:29:5 R regular
# 9549870.chadmin1  AR_hindcast_hi   dikpati           160:33:4 R regular
# 9549871.chadmin1  AR_hindcast_hi   dikpati           159:55:2 R regular
# 9549873.chadmin1  mup5L10          farsoiya          1584:26: R regular
# 9549876.chadmin1  en1_12_2018      avijit            20181:18 R regular
# 9549880.chadmin1  run.b.e21.BSSP3  duvivier          6306:50: R regular
# 9549882.chadmin1  f.e21.F2000BGCc  lantao                   0 Q economy
# 9549883.chadmin1  f.e21.F2000BGCc  lantao                   0 H economy
# 9549894.chadmin1  AR_hindcast_hi   dikpati           158:46:0 R regular
# 9549903.chadmin1  StableMohElie    allouche          282:08:4 R regular
# 9549905.chadmin1  run.b.e21.B1850  hannay                   0 Q regular
# 9549906.chadmin1  st_archive.b.e2  hannay                   0 H regular
# 9549907.chadmin1  AR_hindcast      dikpati           158:10:3 R premium
# 9549908.chadmin1  AR_hindcast_hi   dikpati           158:03:1 R regular
# 9549917.chadmin1  AR_hindcast_hi   dikpati           158:03:5 R regular
# 9549936.chadmin1  test2.run        wanghao           3321:30: R regular
# 9549944.chadmin1  WRF_02           bwallace          937:53:3 R economy
# 9549964.chadmin1  AR_hindcast_hi   dikpati           156:17:0 R regular
# 9549966.chadmin1  metgrid          chliu             309:10:4 R economy
# 9549967.chadmin1  AR_hindcast_hi   dikpati           155:42:3 R regular
# 9549968.chadmin1  AR_hindcast      dikpati           155:00:0 R premium
# 9549969.chadmin1  AR_hindcast_hi   dikpati           155:04:4 R regular
# 9549998.chadmin1  AR_hindcast_hi   dikpati           154:27:4 R regular
# 9550008.chadmin1  AR_hindcast_hi   dikpati           154:29:3 R regular
# 9550018.chadmin1  AR_hindcast_hi   dikpati           153:57:5 R regular
# 9550020.chadmin1  WCG_102_10       mazrooei          199:19:0 R regular
# 9550021.chadmin1  WCG_11_1         arezoo            119:10:0 R regular
# 9550023.chadmin1  AR_hindcast      dikpati           153:54:3 R premium
# 9550029.chadmin1  WCG_13_1         arezoo            120:10:2 R regular
# 9550037.chadmin1  WCG_112_5        mazrooei          101:37:2 R regular
# 9550039.chadmin1  TSMLT6           geostrat                 0 Q regular
# 9550044.chadmin1  WCG_27_0         xfeng             293:21:0 R regular
# 9550045.chadmin1  AR_hindcast      dikpati           152:37:0 R premium
# 9550046.chadmin1  AR_hindcast_hi   dikpati           152:06:5 R regular
# 9550047.chadmin1  AR_hindcast_hi   dikpati           152:03:0 R regular
# 9550050.chadmin1  AR_hindcast      dikpati           152:06:3 R premium
# 9550055.chadmin1  AR_hindcast      dikpati           151:28:2 R premium
# 9550058.chadmin1  AR_hindcast_hi   dikpati           151:24:4 R regular
# 9550061.chadmin1  AR_hindcast_hi   dikpati           151:31:3 R regular
# 9550066.chadmin1  AR_hindcast      dikpati           150:11:2 R premium
# 9550069.chadmin1  TSMLT10          geostrat                 0 Q regular
# 9550092.chadmin1  AR_hindcast      dikpati           149:38:4 R premium
# 9550116.chadmin1  AR_hindcast_hi   dikpati           148:24:1 R regular
# 9550117.chadmin1  TSMLT7           geostrat                 0 Q regular
# 9550120.chadmin1  AR_hindcast      dikpati           148:29:4 R premium
# 9550132.chadmin1  TSMLT8           geostrat                 0 Q regular
# 9550137.chadmin1  AR_hindcast_hi   dikpati           147:51:2 R regular
# 9550142.chadmin1  AR_hindcast_hi   dikpati           147:51:1 R regular
# 9550143.chadmin1  TSMLT9           geostrat                 0 Q regular
# 9550145.chadmin1  AR_hindcast      dikpati           147:48:5 R premium
# 9550151.chadmin1  AR_hindcast      dikpati           147:48:5 R premium
# 9550157.chadmin1  AR_hindcast      dikpati           147:54:2 R premium
# 9550166.chadmin1  AR_hindcast_hi   dikpati           147:19:2 R regular
# 9550199.chadmin1  AR_hindcast_hi   dikpati           146:41:0 R regular
# 9550200.chadmin1  AR_hindcast_hi   dikpati           146:35:1 R regular
# 9550203.chadmin1  shallowles       wangxch           247:57:1 R economy
# 9550205.chadmin1  shallowles       wangxch           247:39:1 R economy
# 9550209.chadmin1  shallowles       wangxch           248:26:5 R economy
# 9550213.chadmin1  AR_hindcast_hi   dikpati           146:40:5 R regular
# 9550217.chadmin1  AR_hindcast_hi   dikpati           146:07:5 R regular
# 9550219.chadmin1  run.emissions-m  lamar             9043:47: R regular
# 9550220.chadmin1  st_archive.emis  lamar                    0 H regular
# 9550225.chadmin1  AR_hindcast_hi   dikpati           146:00:5 R regular
# 9550234.chadmin1  AR_hindcast_hi   dikpati           146:02:1 R regular
# 9550235.chadmin1  AR_hindcast_hi   dikpati           146:02:1 R regular
# 9550236.chadmin1  AR_hindcast_hi   dikpati           146:04:5 R regular
# 9550252.chadmin1  em_real          yutingw           1146:30: R regular
# 9550260.chadmin1  AR_hindcast_hi   dikpati           145:24:0 R regular
# 9550264.chadmin1  mpi_job          cenlinhe          4510:23: R economy
# 9550268.chadmin1  AR_hindcast_hi   dikpati           145:26:4 R regular
# 9550275.chadmin1  WCG_101_4        mazrooei          90:48:22 R regular
# 9550284.chadmin1  AR_hindcast_hi   dikpati           144:55:1 R regular
# 9550294.chadmin1  WCG_102_11       mazrooei          146:32:0 R regular
# 9550295.chadmin1  WCG_11_2         arezoo            109:19:4 R regular
# 9550305.chadmin1  WCG_13_2         arezoo            108:34:2 R regular
# 9550307.chadmin1  AR_hindcast_hi   dikpati           144:12:1 R regular
# 9550329.chadmin1  WCG_112_6        mazrooei          135:26:1 R regular
# 9550330.chadmin1  hub_0            siyuan            3988:06: R economy
# 9550342.chadmin1  WCG_27_1         xfeng             274:39:5 R regular
# 9550348.chadmin1  AR_hindcast      dikpati           143:01:5 R premium
# 9550349.chadmin1  AR_hindcast_hi   dikpati           143:00:3 R regular
# 9550353.chadmin1  AR_hindcast_hi   dikpati           142:59:5 R regular
# 9550357.chadmin1  AR_hindcast_hi   dikpati           143:02:2 R regular
# 9550360.chadmin1  AR_hindcast_hi   dikpati           143:00:1 R regular
# 9550362.chadmin1  hub_1            siyuan                   0 Q economy
# 9550370.chadmin1  AR_hindcast_hi   dikpati           142:26:0 R regular
# 9550373.chadmin1  hub_2            siyuan                   0 Q economy
# 9550374.chadmin1  hub_3            siyuan                   0 Q economy
# 9550382.chadmin1  hub_4            siyuan                   0 Q economy
# 9550390.chadmin1  hub_5            siyuan                   0 Q economy
# 9550397.chadmin1  run_member05.20  ssfcst            263:31:2 R regular
# 9550398.chadmin1  run_member06.20  ssfcst                   0 Q regular
# 9550399.chadmin1  run_member06.20  ssfcst                   0 Q regular
# 9550401.chadmin1  run_member07.20  ssfcst                   0 Q regular
# 9550402.chadmin1  run_member07.20  ssfcst                   0 Q regular
# 9550403.chadmin1  run_member08.20  ssfcst                   0 Q regular
# 9550404.chadmin1  run_member08.20  ssfcst                   0 Q regular
# 9550405.chadmin1  run_member09.20  ssfcst                   0 Q regular
# 9550406.chadmin1  run_member09.20  ssfcst                   0 Q regular
# 9550409.chadmin1  run_member10.20  ssfcst                   0 Q regular
# 9550411.chadmin1  run_member10.20  ssfcst                   0 Q regular
# 9550423.chadmin1  AR_hindcast_hi   dikpati           141:50:3 R regular
# 9550428.chadmin1  AR_hindcast_hi   dikpati           141:20:5 R regular
# 9550461.chadmin1  AR_hindcast_hi   dikpati           140:36:2 R regular
# 9550467.chadmin1  AR_hindcast_hi   dikpati           140:01:2 R regular
# 9550483.chadmin1  AR_hindcast      dikpati           139:24:5 R premium
# 9550767.chadmin1  AR_hindcast_hi   dikpati           137:40:1 R regular
# 9550846.chadmin1  AR_hindcast_hi   dikpati           136:25:4 R regular
# 9550853.chadmin1  AR_hindcast_hi   dikpati           136:22:0 R regular
# 9550854.chadmin1  run_member00.20  ssfcst                   0 Q regular
# 9550855.chadmin1  run_member00.20  ssfcst                   0 Q regular
# 9550872.chadmin1  AR_hindcast_hi   dikpati           136:23:5 R regular
# 9550881.chadmin1  AR_hindcast_hi   dikpati           136:23:5 R regular
# 9550882.chadmin1  run_member01.20  ssfcst                   0 Q regular
# 9550883.chadmin1  run_member01.20  ssfcst                   0 Q regular
# 9550887.chadmin1  AR_hindcast_hi   dikpati           136:23:1 R regular
# 9550888.chadmin1  run_member02.20  ssfcst                   0 Q regular
# 9550889.chadmin1  run_member02.20  ssfcst                   0 Q regular
# 9550891.chadmin1  run_member03.20  ssfcst                   0 Q regular
# 9550892.chadmin1  run_member03.20  ssfcst                   0 Q regular
# 9550893.chadmin1  run_member04.20  ssfcst                   0 Q regular
# 9550894.chadmin1  run_member04.20  ssfcst                   0 Q regular
# 9550895.chadmin1  run_member05.20  ssfcst                   0 Q regular
# 9550896.chadmin1  run_member05.20  ssfcst                   0 Q regular
# 9550897.chadmin1  run_member06.20  ssfcst                   0 Q regular
# 9550898.chadmin1  run_member06.20  ssfcst                   0 Q regular
# ...
# 9563042.chadmin1  wrf              junkyung                 0 Q regular
# 9563043.chadmin1  wrf              junkyung                 0 Q regular
# 9563044.chadmin1  wrf              junkyung                 0 Q regular
# 9563045.chadmin1  wrf              junkyung                 0 Q regular
# 9563046.chadmin1  wrf              junkyung                 0 Q regular
# 9563047.chadmin1  wrf              junkyung                 0 Q regular
# 9563048.chadmin1  wrf              junkyung                 0 Q regular
# 9563049.chadmin1  wrf              junkyung                 0 Q regular
# 9563050.chadmin1  wrf              junkyung                 0 Q regular
# 9563051.chadmin1  wof_adv_mem_20   jmccurry                 0 Q regular
# 9563052.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563053.chadmin1  WCG_104_1        mazrooei          00:01:57 R regular
# 9563054.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563055.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563056.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563057.chadmin1  wof_adv_mem_5    jmccurry                 0 Q regular
# 9563058.chadmin1  wof_adv_mem_5    jmccurry                 0 Q regular
# 9563059.chadmin1  wof_adv_mem_20   jmccurry                 0 Q regular
# 9563060.chadmin1  wof_adv_mem_20   jmccurry                 0 Q regular
# 9563061.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563062.chadmin1  wof_adv_mem_5    jmccurry                 0 Q regular
# 9563064.chadmin1  wof_adv_mem_6    jmccurry                 0 Q regular
# 9563065.chadmin1  wof_adv_mem_6    jmccurry                 0 Q regular
# 9563066.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563067.chadmin1  wof_adv_mem_6    jmccurry                 0 Q regular
# 9563068.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563069.chadmin1  wof_adv_mem_7    jmccurry                 0 Q regular
# 9563070.chadmin1  gridF            jzhai                    0 Q economy
# 9563071.chadmin1  STDIN            glemieux                 0 Q regular
# 9563072.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563073.chadmin1  wof_adv_mem_5    jmccurry                 0 Q regular
# 9563074.chadmin1  wof_filter       jmccurry                 0 Q premium
# 9563075.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563076.chadmin1  wof_filter       jmccurry                 0 Q premium
# 9563077.chadmin1  AR_hindcast_hi   dikpati           00:45:12 R regular
# 9563078.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563079.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563080.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563081.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563082.chadmin1  wof_adv_mem_6    jmccurry                 0 Q regular
# 9563083.chadmin1  wof_adv_mem_6    jmccurry                 0 Q regular
# 9563084.chadmin1  run.PPE_250_ens  trude                    0 Q regular
# 9563085.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563086.chadmin1  wof_adv_mem_6    jmccurry                 0 Q regular
# 9563087.chadmin1  wof_adv_mem_7    jmccurry                 0 Q regular
# 9563088.chadmin1  wof_adv_mem_7    jmccurry                 0 Q regular
# 9563089.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563090.chadmin1  wof_adv_mem_7    jmccurry                 0 Q regular
# 9563091.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563092.chadmin1  wof_adv_mem_8    jmccurry                 0 Q regular
# 9563093.chadmin1  gridF            jzhai                    0 Q economy
# 9563094.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563095.chadmin1  wof_adv_mem_6    jmccurry                 0 Q regular
# 9563096.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563097.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563099.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563100.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563101.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563102.chadmin1  wof_adv_mem_7    jmccurry                 0 Q regular
# 9563103.chadmin1  wof_adv_mem_7    jmccurry                 0 Q regular
# 9563105.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563106.chadmin1  wof_adv_mem_7    jmccurry                 0 Q regular
# 9563107.chadmin1  wof_adv_mem_8    jmccurry                 0 Q regular
# 9563108.chadmin1  wof_adv_mem_8    jmccurry                 0 Q regular
# 9563109.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563110.chadmin1  wof_adv_mem_8    jmccurry                 0 Q regular
# 9563111.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563112.chadmin1  wof_adv_mem_9    jmccurry                 0 Q regular
# 9563113.chadmin1  gridF            jzhai                    0 Q economy
# 9563114.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563115.chadmin1  wof_adv_mem_7    jmccurry                 0 Q regular
# 9563116.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563117.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563118.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563119.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563120.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563121.chadmin1  wof_adv_mem_8    jmccurry                 0 Q regular
# 9563122.chadmin1  wof_adv_mem_8    jmccurry                 0 Q regular
# 9563123.chadmin1  NODA109A.wrf.71  syha                     0 Q regular
# 9563124.chadmin1  NODA109.wrf.92   syha                     0 Q regular
# 9563125.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563126.chadmin1  wof_adv_mem_8    jmccurry                 0 Q regular
# 9563127.chadmin1  wof_adv_mem_9    jmccurry                 0 Q regular
# 9563128.chadmin1  wof_adv_mem_9    jmccurry                 0 Q regular
# 9563129.chadmin1  run.PPE_250_ens  trude                    0 Q regular
# 9563130.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563131.chadmin1  wof_adv_mem_9    jmccurry                 0 Q regular
# 9563132.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563133.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563134.chadmin1  gridF            jzhai                    0 Q economy
# 9563135.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563136.chadmin1  wof_adv_mem_8    jmccurry                 0 Q regular
# 9563137.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563138.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563139.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563140.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563141.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563142.chadmin1  wof_adv_mem_9    jmccurry                 0 Q regular
# 9563143.chadmin1  wof_adv_mem_9    jmccurry                 0 Q regular
# 9563144.chadmin1  timeseries       mollyw                   0 Q regular
# 9563145.chadmin1  wof_adv_mem_9    jmccurry                 0 Q regular
# 9563146.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563147.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563149.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563150.chadmin1  wof_adv_mem_16   jmccurry                 0 Q regular
# 9563151.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563152.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563153.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563154.chadmin1  gridF            jzhai                    0 Q economy
# 9563155.chadmin1  wof_adv_mem_16   jmccurry                 0 Q regular
# 9563156.chadmin1  wof_adv_mem_9    jmccurry                 0 Q regular
# 9563157.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563158.chadmin1  wof_adv_mem_16   jmccurry                 0 Q regular
# 9563159.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563160.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563161.chadmin1  wof_adv_mem_16   jmccurry                 0 Q regular
# 9563162.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563163.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563164.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563165.chadmin1  wof_adv_mem_16   jmccurry                 0 Q regular
# 9563166.chadmin1  postprocess_mem  ssfcst                   0 Q regular
# 9563167.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563168.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563169.chadmin1  wof_adv_mem_17   jmccurry                 0 Q regular
# 9563170.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563171.chadmin1  wof_adv_mem_16   jmccurry                 0 Q regular
# 9563172.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563173.chadmin1  extract_PRECL_g  ebednarz                 0 Q economy
# 9563174.chadmin1  gridF            jzhai                    0 Q economy
# 9563175.chadmin1  wof_adv_mem_17   jmccurry                 0 Q regular
# 9563176.chadmin1  run.PPE_250_ens  trude                    0 Q regular
# 9563177.chadmin1  wof_adv_mem_10   jmccurry                 0 Q regular
# 9563178.chadmin1  wof_adv_mem_16   jmccurry                 0 Q regular
# 9563179.chadmin1  wof_adv_mem_17   jmccurry                 0 Q regular
# 9563180.chadmin1  wof_adv_mem_16   jmccurry                 0 Q regular
# 9563181.chadmin1  wof_adv_mem_16   jmccurry                 0 Q regular
# 9563182.chadmin1  wof_adv_mem_17   jmccurry                 0 Q regular
# 9563183.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563184.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563185.chadmin1  100percent       antliya                  0 Q regular
# 9563186.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563187.chadmin1  wof_adv_mem_17   jmccurry                 0 Q regular
# 9563188.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563189.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563190.chadmin1  wof_adv_mem_18   jmccurry                 0 Q regular
# 9563191.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563192.chadmin1  wof_adv_mem_17   jmccurry                 0 Q regular
# 9563193.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563194.chadmin1  extract_PRECL_g  ebednarz                 0 Q economy
# 9563195.chadmin1  gridF            jzhai                    0 Q economy
# 9563197.chadmin1  wof_adv_mem_17   jmccurry                 0 Q regular
# 9563198.chadmin1  wof_adv_mem_18   jmccurry                 0 Q regular
# 9563199.chadmin1  wof_adv_mem_11   jmccurry                 0 Q regular
# 9563200.chadmin1  wof_adv_mem_18   jmccurry                 0 Q regular
# 9563201.chadmin1  wof_adv_mem_17   jmccurry                 0 Q regular
# 9563202.chadmin1  wof_adv_mem_18   jmccurry                 0 Q regular
# 9563203.chadmin1  wof_adv_mem_17   jmccurry                 0 Q regular
# 9563204.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563205.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563206.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563207.chadmin1  wof_adv_mem_18   jmccurry                 0 Q regular
# 9563208.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563209.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563210.chadmin1  wof_adv_mem_19   jmccurry                 0 Q regular
# 9563211.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563212.chadmin1  wof_adv_mem_18   jmccurry                 0 Q regular
# 9563213.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563214.chadmin1  extract_PRECL_g  ebednarz                 0 Q economy
# 9563215.chadmin1  wof_adv_mem_18   jmccurry                 0 Q regular
# 9563216.chadmin1  wof_adv_mem_19   jmccurry                 0 Q regular
# 9563217.chadmin1  wof_adv_mem_12   jmccurry                 0 Q regular
# 9563218.chadmin1  wof_adv_mem_19   jmccurry                 0 Q regular
# 9563219.chadmin1  wof_adv_mem_18   jmccurry                 0 Q regular
# 9563220.chadmin1  wof_adv_mem_19   jmccurry                 0 Q regular
# 9563221.chadmin1  wof_adv_mem_18   jmccurry                 0 Q regular
# 9563222.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563223.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563224.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563225.chadmin1  run.PPE_250_ens  trude                    0 Q regular
# 9563226.chadmin1  wof_adv_mem_19   jmccurry                 0 Q regular
# 9563227.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563228.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563229.chadmin1  wof_adv_mem_20   jmccurry                 0 Q regular
# 9563230.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563231.chadmin1  wof_adv_mem_19   jmccurry                 0 Q regular
# 9563232.chadmin1  wof_adv_mem_19   jmccurry                 0 Q regular
# 9563233.chadmin1  wof_adv_mem_15   jmccurry                 0 Q regular
# 9563234.chadmin1  extract_PRECL_g  ebednarz                 0 Q economy
# 9563235.chadmin1  wof_adv_mem_20   jmccurry                 0 Q regular
# 9563236.chadmin1  wof_adv_mem_13   jmccurry                 0 Q regular
# 9563237.chadmin1  wof_adv_mem_20   jmccurry                 0 Q regular
# 9563238.chadmin1  wof_adv_mem_19   jmccurry                 0 Q regular
# 9563239.chadmin1  wof_adv_mem_20   jmccurry                 0 Q regular
# 9563240.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563241.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563242.chadmin1  wof_adv_mem_14   jmccurry                 0 Q regular
# 9563243.chadmin1  wof_adv_mem_19   jmccurry                 0 Q regular

# %%
cluster.close()

# %%
stores

# %%
ds = xr.open_zarr(store.as_posix(), consolidated=True)

# %%
ds

# %%
    data_vars = [vname for vname in ds.data_vars]
data_vars

# %%
    data_var = data_vars[0]
    store_name = store.as_posix().split('/')[-1]
    
    # Only produce plots that haven't been created already.  
    plotdir = plot_directory + store_name

# %%
plotdir

# %%
plt.show()
